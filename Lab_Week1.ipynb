# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Econ441B/SeoulBikeData2.csv")
df
# Out:
#             Date  Rented Bike Count  Hour  Temperature  Humidity  Wind speed  \
# 0     01/12/2017                254     0         -5.2        37         2.2
# 1     01/12/2017                204     1         -5.5        38         0.8
# 2     01/12/2017                173     2         -6.0        39         1.0
# 3     01/12/2017                107     3         -6.2        40         0.9
# 4     01/12/2017                 78     4         -6.0        36         2.3
# ...          ...                ...   ...          ...       ...         ...
# 8755  30/11/2018               1003    19          4.2        34         2.6
# 8756  30/11/2018                764    20          3.4        37         2.3
# 8757  30/11/2018                694    21          2.6        39         0.3
# 8758  30/11/2018                712    22          2.1        41         1.0
# 8759  30/11/2018                584    23          1.9        43         1.3
#
# ...

# %%
# df.set_index("Date", inplace = True)
# df.index = pd.to_datetime(df.index)

# %%
# plt.figure(figsize = (12,5))
# plt.plot(df["Close"])
# plt.title("VIX INDEX")
# plt.xlabel("Date")
# plt.ylabel("VIX")
# plt.grid()
# plt.show()

# %%
plt.hist(df['Rented Bike Count'], alpha = 0.5)
plt.title("Histogram of Rented Bike Count")
plt.xlabel("Number of bikes")
plt.ylabel("Frequency")
plt.grid()
plt.show()

# %%
# the histogram shows that the data points are right-skewed. 
# Most of the daily rented bike counts fall into 0-1000.
